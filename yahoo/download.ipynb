# %%
import warnings
import yfinance as yf
warnings.simplefilter(action='ignore', category=FutureWarning)

# Get the data for the stock AAPL
df0 = yf.download(['AAPL', 'AMZN', 'BABA', 'BIDU', 'GOOG', 'IBM', 'JD', 'META', 'MSFT', 'ORCL', 'PDD', 'UBER'], '2014-01-01')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
df0['Adj Close'].plot()
plt.show()
# Out:
# [*********************100%%**********************]  12 of 12 completed

# %%
print(df0.head())
# Out:
# Price       Adj Close                                                         \
# Ticker           AAPL       AMZN BABA        BIDU       GOOG         IBM  JD
# Date
# 2014-01-02  17.296658  19.898500  NaN  179.990005  27.724083  115.518181 NaN
# 2014-01-03  16.916721  19.822001  NaN  175.279999  27.521841  116.209328 NaN
# 2014-01-06  17.008965  19.681499  NaN  176.630005  27.828691  115.810852 NaN
# 2014-01-07  16.887325  19.901501  NaN  178.820007  28.365179  118.120827 NaN
# 2014-01-08  16.994272  20.096001  NaN  181.789993  28.424210  117.037392 NaN
#
# Price                                        ... Volume                      \
# Ticker           META       MSFT       ORCL  ...   BABA     BIDU       GOOG
# Date                                         ...
# 2014-01-02  54.709999  31.233065  32.275028  ...    NaN  4702400   73129082
# 2014-01-03  54.560001  31.022936  32.189453  ...    NaN  3382200   66917888
# 2014-01-06  57.200001  30.367346  32.061111  ...    NaN  2858700   71037271
# 2014-01-07  57.919998  30.602688  32.386250  ...    NaN  2480500  102486711
# 2014-01-08  58.230000  30.056364  32.275028  ...    NaN  3441900   90036218
#
# Price
# Ticker          IBM  JD      META      MSFT      ORCL PDD UBER
# Date
# 2014-01-02  4755639 NaN  43195500  30632200  18162100 NaN  NaN
# 2014-01-03  4250107 NaN  38246200  31134800  11693900 NaN  NaN
# 2014-01-06  4254919 NaN  68852600  43603700  15329400 NaN  NaN
# 2014-01-07  6205186 NaN  77207400  35802800  16792200 NaN  NaN
# 2014-01-08  4815470 NaN  56682400  59971700  16111600 NaN  NaN
#
# [5 rows x 72 columns]

# %%
print(type(df0))
df0.to_csv('../data/test_yahoo.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df0.size)
print(df0.shape)
print(df0.ndim)
print(df0.columns)
# Out:
# 183528
# (2549, 72)
# 2
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close', 'AMZN'),
#             ('Adj Close', 'BABA'),
#             ('Adj Close', 'BIDU'),
#             ('Adj Close', 'GOOG'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close',   'JD'),
#             ('Adj Close', 'META'),
#             ('Adj Close', 'MSFT'),
#             ('Adj Close', 'ORCL'),
#             ('Adj Close',  'PDD'),
#             ('Adj Close', 'UBER'),
#             (    'Close', 'AAPL'),
#             (    'Close', 'AMZN'),
#             (    'Close', 'BABA'),
#             (    'Close', 'BIDU'),
#             (    'Close', 'GOOG'),
#             (    'Close',  'IBM'),
#             (    'Close',   'JD'),
#             (    'Close', 'META'),
#             (    'Close', 'MSFT'),
#             (    'Close', 'ORCL'),
#             (    'Close',  'PDD'),
#             (    'Close', 'UBER'),
#             (     'High', 'AAPL'),
#             (     'High', 'AMZN'),
#             (     'High', 'BABA'),
#             (     'High', 'BIDU'),
#             (     'High', 'GOOG'),
#             (     'High',  'IBM'),
#             (     'High',   'JD'),
#             (     'High', 'META'),
#             (     'High', 'MSFT'),
#             (     'High', 'ORCL'),
#             (     'High',  'PDD'),
#             (     'High', 'UBER'),
#             (      'Low', 'AAPL'),
#             (      'Low', 'AMZN'),
#             (      'Low', 'BABA'),
#             (      'Low', 'BIDU'),
#             (      'Low', 'GOOG'),
#             (      'Low',  'IBM'),
#             (      'Low',   'JD'),
#             (      'Low', 'META'),
#             (      'Low', 'MSFT'),
#             (      'Low', 'ORCL'),
#             (      'Low',  'PDD'),
#             (      'Low', 'UBER'),
#             (     'Open', 'AAPL'),
#             (     'Open', 'AMZN'),
#             (     'Open', 'BABA'),
#             (     'Open', 'BIDU'),
#             (     'Open', 'GOOG'),
#             (     'Open',  'IBM'),
#             (     'Open',   'JD'),
#             (     'Open', 'META'),
#             (     'Open', 'MSFT'),
#             (     'Open', 'ORCL'),
#             (     'Open',  'PDD'),
#             (     'Open', 'UBER'),
#             (   'Volume', 'AAPL'),
#             (   'Volume', 'AMZN'),
#             (   'Volume', 'BABA'),
#             (   'Volume', 'BIDU'),
#             (   'Volume', 'GOOG'),
#             (   'Volume',  'IBM'),
#             (   'Volume',   'JD'),
#             (   'Volume', 'META'),
#             (   'Volume', 'MSFT'),
#             (   'Volume', 'ORCL'),
#             (   'Volume',  'PDD'),
#             (   'Volume', 'UBER')],
#            names=['Price', 'Ticker'])

# %%
import numpy as np
plt.plot(df0['Adj Close']['META'], label='META')
plt.plot(df0['Adj Close']['GOOG'], label='GOOG')
plt.plot(df0['Adj Close']['PDD'], label='PDD')
plt.plot(df0['Adj Close']['MSFT'], label='MSFT')
plt.plot(df0['Adj Close']['BABA'], label='BABA')
plt.legend()
plt.show()

print(df0['Adj Close']['META'].head())
print(list(df0['Adj Close']['META']))
# Out:
# Date
# 2014-01-02    54.709999
# 2014-01-03    54.560001
# 2014-01-06    57.200001
# 2014-01-07    57.919998
# 2014-01-08    58.230000
# Name: META, dtype: float64
# [54.709999084472656, 54.560001373291016, 57.20000076293945, 57.91999816894531, 58.22999954223633, 57.220001220703125, 57.939998626708984, 55.90999984741211, 57.7400016784668, 57.599998474121094, 57.189998626708984, 56.29999923706055, 58.5099983215332, 57.5099983215332, 56.630001068115234, 54.45000076293945, 53.54999923706055, 55.13999938964844, 53.529998779296875, 61.08000183105469, 62.56999969482422, 61.47999954223633, 62.75, 62.189998626708984, 62.15999984741211, 64.31999969482422, 63.54999923706055, 64.8499984741211, 64.44999694824219, 67.33000183105469, 67.08999633789062, 67.30000305175781, 68.05999755859375, 69.62999725341797, 68.58999633789062, 70.77999877929688, 69.8499984741211, 69.26000213623047, 68.94000244140625, 68.45999908447266, 67.41000366210938, 68.80000305175781, 71.56999969482422, 70.83999633789062, 69.80000305175781, 72.02999877929688, 70.0999984741211, 70.87999725341797, 68.83000183105469, 67.72000122070312, 68.73999786376953, 69.19000244140625, 68.23999786376953, 66.97000122070312, 67.23999786376953, 64.0999984741211, 64.88999938964844, 60.38999938964844, 60.970001220703125, 60.0099983215332, 60.2400016784668, 62.619998931884766, 62.720001220703125, 59.4900016784668, 56.75, 56.95000076293945, 58.189998626708984, 62.40999984741211, 59.15999984741211, 58.529998779296875, 58.88999938964844, 59.09000015258789, 59.720001220703125, 58.939998626708984, 61.2400016784668, 63.029998779296875, 61.36000061035156, 60.869998931884766, 57.709999084472656, 56.13999938964844, 58.150001525878906, 59.779998779296875, 61.150001525878906, 60.459999084472656, 61.220001220703125, 58.529998779296875, 57.38999938964844, 56.7599983215332, 57.2400016784668, 59.83000183105469, 59.83000183105469, 59.22999954223633, 57.91999816894531, 58.02000045776367, 59.209999084472656, 58.560001373291016, 60.4900016784668, 60.52000045776367, 61.349998474121094, 63.47999954223633, 63.5099983215332, 63.83000183105469, 63.29999923706055, 63.08000183105469, 62.869998931884766, 63.34000015258789, 63.189998626708984, 62.5, 62.880001068115234, 65.7699966430664, 65.77999877929688, 64.29000091552734, 64.5, 64.19000244140625, 64.4000015258789, 65.5999984741211, 64.33999633789062, 64.5, 65.37000274658203, 65.72000122070312, 67.44000244140625, 67.12999725341797, 67.5999984741211, 67.29000091552734, 68.05999755859375, 66.44999694824219, 66.29000091552734, 65.29000091552734, 62.7599983215332, 64.97000122070312, 64.87000274658203, 66.33999633789062, 67.9000015258789, 67.16999816894531, 67.66000366210938, 66.41000366210938, 68.41999816894531, 69.4000015258789, 69.2699966430664, 71.29000091552734, 74.9800033569336, 75.19000244140625, 74.91999816894531, 73.70999908447266, 74.68000030517578, 72.6500015258789, 72.36000061035156, 73.51000213623047, 72.69000244140625, 72.47000122070312, 73.16999816894531, 73.05999755859375, 73.44000244140625, 72.83000183105469, 73.7699966430664, 74.30000305175781, 73.62999725341797, 74.58999633789062, 75.29000091552734, 74.80999755859375, 74.56999969482422, 74.56999969482422, 75.0199966430664, 75.95999908447266, 74.62999725341797, 73.86000061035156, 74.81999969482422, 76.68000030517578, 75.83000183105469, 75.94999694824219, 77.26000213623047, 77.88999938964844, 76.66999816894531, 77.43000030517578, 77.91999816894531, 77.4800033569336, 74.58000183105469, 76.08000183105469, 76.43000030517578, 77.0, 77.91000366210938, 76.80000305175781, 78.29000091552734, 78.54000091552734, 77.22000122070312, 78.79000091552734, 79.0, 79.04000091552734, 76.55000305175781, 77.08000183105469, 77.44000244140625, 77.55999755859375, 76.29000091552734, 77.5199966430664, 75.91000366210938, 72.91000366210938, 72.98999786376953, 73.58999633789062, 73.20999908447266, 72.62999725341797, 75.94999694824219, 76.94999694824219, 78.69000244140625, 78.37000274658203, 80.04000091552734, 80.66999816894531, 80.27999877929688, 80.7699966430664, 75.86000061035156, 74.11000061035156, 74.98999786376953, 73.87999725341797, 75.76000213623047, 74.83000183105469, 75.26000213623047, 75 ...

# %%
print(df0.index)
print(df0.columns)
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2024-02-05', '2024-02-06', '2024-02-07', '2024-02-08',
#                '2024-02-09', '2024-02-12', '2024-02-13', '2024-02-14',
#                '2024-02-15', '2024-02-16'],
#               dtype='datetime64[ns]', name='Date', length=2549, freq=None)
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close', 'AMZN'),
#             ('Adj Close', 'BABA'),
#             ('Adj Close', 'BIDU'),
#             ('Adj Close', 'GOOG'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close',   'JD'),
#             ('Adj Close', 'META'),
#             ('Adj Close', 'MSFT'),
#             ('Adj Close', 'ORCL'),
#             ('Adj Close',  'PDD'),
#             ('Adj Close', 'UBER'),
#             (    'Close', 'AAPL'),
#             (    'Close', 'AMZN'),
#             (    'Close', 'BABA'),
#             (    'Close', 'BIDU'),
#             (    'Close', 'GOOG'),
#             (    'Close',  'IBM'),
#             (    'Close',   'JD'),
#             (    'Close', 'META'),
#             (    'Close', 'MSFT'),
#             (    'Close', 'ORCL'),
#             (    'Close',  'PDD'),
#             (    'Close', 'UBER'),
#             (     'High', 'AAPL'),
#             (     'High', 'AMZN'),
#             (     'High', 'BABA'),
#             (     'High', 'BIDU'),
#             (     'High', 'GOOG'),
#             (     'High',  'IBM'),
#             (     'High',   'JD'),
#             (     'High', 'META'),
#             (     'High', 'MSFT'),
#             (     'High', 'ORCL'),
#             (     'High',  'PDD'),
#             (     'High', 'UBER'),
#             (      'Low', 'AAPL'),
#             (      'Low', 'AMZN'),
#             (      'Low', 'BABA'),
#             (      'Low', 'BIDU'),
#             (      'Low', 'GOOG'),
#             (      'Low',  'IBM'),
#             (      'Low',   'JD'),
#             (      'Low', 'META'),
#             (      'Low', 'MSFT'),
#             (      'Low', 'ORCL'),
#             (      'Low',  'PDD'),
#             (      'Low', 'UBER'),
#             (     'Open', 'AAPL'),
#             (     'Open', 'AMZN'),
#             (     'Open', 'BABA'),
#             (     'Open', 'BIDU'),
#             (     'Open', 'GOOG'),
#             (     'Open',  'IBM'),
#             (     'Open',   'JD'),
#             (     'Open', 'META'),
#             (     'Open', 'MSFT'),
#             (     'Open', 'ORCL'),
#             (     'Open',  'PDD'),
#             (     'Open', 'UBER'),
#             (   'Volume', 'AAPL'),
#             (   'Volume', 'AMZN'),
#             (   'Volume', 'BABA'),
#             (   'Volume', 'BIDU'),
#             (   'Volume', 'GOOG'),
#             (   'Volume',  'IBM'),
#             (   'Volume',   'JD'),
#             (   'Volume', 'META'),
#             (   'Volume', 'MSFT'),
#             (   'Volume', 'ORCL'),
#             (   'Volume',  'PDD'),
#             (   'Volume', 'UBER')],
#            names=['Price', 'Ticker'])

# %%
df1 = df0['Adj Close']
print(df1.head())
print(df1.tail())
print(df1.shape)
print(df1.columns)
df1.plot()
plt.show()
# Out:
# Ticker           AAPL       AMZN  BABA        BIDU       GOOG         IBM  JD  \
# Date
# 2014-01-02  17.296658  19.898500   NaN  179.990005  27.724083  115.518181 NaN
# 2014-01-03  16.916721  19.822001   NaN  175.279999  27.521841  116.209328 NaN
# 2014-01-06  17.008965  19.681499   NaN  176.630005  27.828691  115.810852 NaN
# 2014-01-07  16.887325  19.901501   NaN  178.820007  28.365179  118.120827 NaN
# 2014-01-08  16.994272  20.096001   NaN  181.789993  28.424210  117.037392 NaN
#
# Ticker           META       MSFT       ORCL  PDD  UBER
# Date
# 2014-01-02  54.709999  31.233065  32.275028  NaN   NaN
# 2014-01-03  54.560001  31.022936  32.189453  NaN   NaN
# 2014-01-06  57.200001  30.367346  32.061111  NaN   NaN
# 2014-01-07  57.919998  30.602688  32.386250  NaN   NaN
# 2014-01-08  58.230000  30.056364  32.275028  NaN   NaN
# Ticker            AAPL        AMZN       BABA        BIDU        GOOG  \
# Date
# 2024-02-12  187.149994  172.339996  73.139999  106.709999  148.729996
# 2024-02-13  185.039993  168.639999  71.599998  103.809998  146.369995
# 2024-02-14  184.149994  170.979996  73.389999  106.709999  147.139999
# 2024-02-15  183.860001  169.800003  73.820000  106.839996  143.940002
# 2024-02-16  182.309998  169.509995  73.910004  107.120003  141.759995
#
# Ticker             IBM         JD        META        MSFT        ORCL  \
# Date
# 2024-02-12  186.160004  22.889999  468.899994  414.493500  115.839996
# 2024-02-13  183.699997  22.129999  460.119995  405.570007  113.680000
# 2024-02-14  183.570007  23.139999  473.279999  409.489990  114.260002
# 2024-02-15  186.869995  23.559999  484.029999  406.559998  112.779999
# 2024-02-16  187.639999  24.219999  473.320007  404.059998  111.309998
#
# Ticker             PDD       UBER
# Date
# 2024-02-12  131.570007  69.120003
# 2024-02-13  129.039993  68.989998
# 2024-02-14  132.009995  79.150002
# 2024-02-15  135.320007  81.389999
# 2024-02-16  135.259995  78.410004
# (2549, 12)
# Index(['AAPL', 'AMZN', 'BABA', 'BIDU', 'GOOG', 'IBM', 'JD', 'META', 'MSFT',
#        'ORCL', 'PDD', 'UBER'],
#       dtype='object', name='Ticker')

# %%
import pandas as pd
df_price = df1.loc[(df1.index >= '2023-01-01') & (df1.index < '2024-01-01')]
print(df_price.head())
print(df_price.tail())
print(df_price.shape)
print(df_price.columns)
df_price.to_csv('../data/adj_close_2023.csv')
df_price.plot()
plt.show()
# Out:
# Ticker            AAPL       AMZN        BABA        BIDU       GOOG  \
# Date
# 2023-01-03  124.216301  85.820000   90.759949  119.129997  89.699997
# 2023-01-04  125.497498  85.139999  102.541565  131.759995  88.709999
# 2023-01-05  124.166649  83.120003  103.192818  132.529999  86.769997
# 2023-01-06  128.735245  86.080002  105.975410  133.059998  88.160004
# 2023-01-09  129.261612  87.360001  109.359917  133.389999  88.800003
#
# Ticker             IBM         JD        META        MSFT       ORCL  \
# Date
# 2023-01-03  133.634216  56.785870  124.739998  237.036011  82.148880
# 2023-01-04  134.625488  65.120506  127.370003  226.667282  82.894615
# 2023-01-05  133.218811  64.923470  126.940002  219.949387  82.727806
# 2023-01-06  135.663971  63.347183  130.020004  222.541534  84.052475
# 2023-01-09  135.522354  62.194519  129.470001  224.708282  85.116173
#
# Ticker            PDD       UBER
# Date
# 2023-01-03  84.529999  25.360001
# 2023-01-04  91.059998  25.910000
# 2023-01-05  95.430000  25.549999
# 2023-01-06  95.959999  26.400000
# 2023-01-09  95.519997  27.400000
# Ticker            AAPL        AMZN       BABA        BIDU        GOOG  \
# Date
# 2023-12-22  193.353287  153.419998  75.279999  114.739998  142.720001
# 2023-12-26  192.803986  153.410004  75.849998  114.669998  142.820007
# 2023-12-27  192.903839  153.339996  76.110001  114.389999  141.440002
# 2023-12-28  193.333298  153.380005  77.239998  117.820000  141.279999
# 2023-12-29  192.284637  151.940002  77.510002  119.089996  140.929993
#
# Ticker             IBM         JD        META        MSFT        ORCL  \
# Date
# 2023-12-22  160.675140  27.590000  353.390015  373.888580  105.790077
# 2023-12-26  161.735489  27.610001  354.829987  373.968445  105.780121
# 2023-12-27  161.983231  27.750000  357.829987  373.379547  105.531090
# 2023-12-28  162.270599  28.510000  358.320007  374.587280  105.839890
# 2023-12-29  162.072403  28.889999  353.959991  375.345886  105.023056
#
# Ticker             PDD       UBER
# Date
# 2023-12-22  144.479996  61.709999
# 2023-12-26  145.220001  61.980000
# 2023-12-27  144.449997  63.279999
# 2023-12-28  145.350006  63.139999
# 2023-12-29  146.309998  61.570000
# (250, 12)
# Index(['AAPL', 'AMZN', 'BABA', 'BIDU', 'GOOG', 'IBM', 'JD', 'META', 'MSFT',
#        'ORCL', 'PDD', 'UBER'],
#       dtype='object', name='Ticker')

# %%
df_ret = df_price.pct_change()*252
print(df_ret.head())
print(df_ret.tail())
df_ret.plot()
plt.show()
# Out:
# Ticker          AAPL      AMZN       BABA       BIDU      GOOG       IBM  \
# Date
# 2023-01-03       NaN       NaN        NaN        NaN       NaN       NaN
# 2023-01-04  2.599188 -1.996738  32.712307  26.716691 -2.781265  1.869286
# 2023-01-05 -2.672355 -5.978848   1.600480   1.472686 -5.510998 -2.633102
# 2023-01-06  9.272105  8.974010   6.795176   1.007770  4.036900  4.625325
# 2023-01-09  1.030367  3.747208   8.048052   0.624985  1.829399 -0.263058
#
# Ticker             JD      META       MSFT      ORCL        PDD      UBER
# Date
# 2023-01-03        NaN       NaN        NaN       NaN        NaN       NaN
# 2023-01-04  36.986815  5.313141 -11.023302  2.287618  19.467168  5.465292
# 2023-01-05  -0.762483 -0.850750  -7.468699 -0.507100  12.093573 -3.501357
# 2023-01-06  -6.118344  6.114388   2.969871  4.035119   1.399557  8.383566
# 2023-01-09  -4.585387 -1.065996   2.453567  3.189101  -1.155488  9.545455
# Ticker          AAPL      AMZN      BABA      BIDU      GOOG       IBM  \
# Date
# 2023-12-22 -1.397953 -0.687985 -3.238406 -6.149483  1.634976  2.131615
# 2023-12-26 -0.715912 -0.016416  1.908076 -0.153738  0.176580  1.663032
# 2023-12-27  0.130511 -0.114998  0.863817 -0.615328 -2.434962  0.386006
# 2023-12-28  0.561023  0.065750  3.741418  7.556256 -0.285074  0.447064
# 2023-12-29 -1.366875 -2.365893  0.880905  2.716340 -0.624303 -0.307791
#
# Ticker            JD      META      MSFT      ORCL       PDD      UBER
# Date
# 2023-12-22 -3.512503 -0.498165  0.701595  0.809362 -3.847338  1.025057
# 2023-12-26  0.182679  1.026834  0.053828 -0.023717  1.290707  1.102578
# 2023-12-27  1.277792  2.130598 -0.396831 -0.593267 -1.336187  5.285573
# 2023-12-28  6.901624  0.345095  0.815119  0.737390  1.570109 -0.557520
# 2023-12-29  3.358814 -3.066321  0.510345 -1.944844  1.664381 -6.266074

# %%
plt.plot(df_ret['PDD'], label='PDD')
plt.plot(df_ret['META'], label='META')
plt.legend()
plt.show()

# %%
df_price_diff = df_price.diff()
print(df_price_diff.head())
print(df_price_diff.tail())
df_price_diff.plot()
plt.show()
