# %%
import yfinance as yf

# Get the data for the stock AAPL
#data = yf.download(['META', 'GOOG', 'AMZN','MSFT', 'AAPL'],'2014-01-01','2024-02-16')
df = yf.download(['META', 'GOOG', 'AMZN','MSFT', 'AAPL'],'2014-01-01')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
df['Adj Close'].plot()
plt.show()
# Out:
# /home/hliu/anaconda3/lib/python3.9/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /home/hliu/anaconda3/lib/python3.9/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]/home/hliu/anaconda3/lib/python3.9/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /home/hliu/anaconda3/lib/python3.9/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /home/hliu/anaconda3/lib/python3.9/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  5 of 5 completed

# %%
print(df.head())
# Out:
# Price       Adj Close                                                  Close  \
# Ticker           AAPL       AMZN       GOOG       META       MSFT       AAPL
# Date
# 2014-01-02  17.296656  19.898500  27.724083  54.709999  31.233055  19.754642
# 2014-01-03  16.916725  19.822001  27.521841  54.560001  31.022942  19.320715
# 2014-01-06  17.008963  19.681499  27.828691  57.200001  30.367361  19.426071
# 2014-01-07  16.887333  19.901501  28.365179  57.919998  30.602682  19.287144
# 2014-01-08  16.994274  20.096001  28.424210  58.230000  30.056360  19.409286
#
# Price                                                   ...       Open  \
# Ticker           AMZN       GOOG       META       MSFT  ...       AAPL
# Date                                                    ...
# 2014-01-02  19.898500  27.724083  54.709999  37.160000  ...  19.845715
# 2014-01-03  19.822001  27.521841  54.560001  36.910000  ...  19.745001
# 2014-01-06  19.681499  27.828691  57.200001  36.130001  ...  19.194643
# 2014-01-07  19.901501  28.365179  57.919998  36.410000  ...  19.440001
# 2014-01-08  20.096001  28.424210  58.230000  35.759998  ...  19.243214
#
# Price                                                      Volume            \
# Ticker           AMZN       GOOG       META       MSFT       AAPL      AMZN
# Date
# 2014-01-02  19.940001  27.782366  54.830002  37.349998  234684800  42756000
# 2014-01-03  19.914499  27.770908  55.020000  37.200001  392467600  44204000
# 2014-01-06  19.792500  27.721344  54.419998  36.849998  412610800  63412000
# 2014-01-07  19.752001  28.019974  57.700001  36.330002  317209200  38320000
# 2014-01-08  19.923500  28.543015  57.599998  36.000000  258529600  46330000
#
# Price
# Ticker           GOOG      META      MSFT
# Date
# 2014-01-02   73129082  43195500  30632200
# 2014-01-03   66917888  38246200  31134800
# 2014-01-06   71037271  68852600  43603700
# 2014-01-07  102486711  77207400  35802800
# 2014-01-08   90036218  56682400  59971700
#
# [5 rows x 30 columns]

# %%
print(type(df))
df.to_csv('../data/test_yahoo.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import yfinance as yf

# Get the data for the stock AAPL
df = yf.download(['ABC'],'2014-01-01','2024-02-16')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
df['Adj Close'].plot()
plt.show()
