# %%
import warnings
import yfinance as yf
warnings.simplefilter(action='ignore', category=FutureWarning)

# Get the data for the stock AAPL
df = yf.download(['AAPL', 'AMZN', 'BABA', 'BIDU', 'GOOG', 'IBM', 'JD', 'META', 'MSFT', 'ORCL', 'PDD', 'UBER'], '2014-01-01')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
df['Adj Close'].plot()
plt.show()
# Out:
# [*********************100%%**********************]  12 of 12 completed

# %%
print(df.head())
# Out:
# Price       Adj Close                                                         \
# Ticker           AAPL       AMZN BABA        BIDU       GOOG         IBM  JD
# Date
# 2014-01-02  17.296656  19.898500  NaN  179.990005  27.724083  115.518196 NaN
# 2014-01-03  16.916723  19.822001  NaN  175.279999  27.521841  116.209297 NaN
# 2014-01-06  17.008970  19.681499  NaN  176.630005  27.828691  115.810829 NaN
# 2014-01-07  16.887325  19.901501  NaN  178.820007  28.365179  118.120827 NaN
# 2014-01-08  16.994270  20.096001  NaN  181.789993  28.424210  117.037422 NaN
#
# Price                                        ... Volume                      \
# Ticker           META       MSFT       ORCL  ...   BABA     BIDU       GOOG
# Date                                         ...
# 2014-01-02  54.709999  31.233049  32.275028  ...    NaN  4702400   73129082
# 2014-01-03  54.560001  31.022938  32.189453  ...    NaN  3382200   66917888
# 2014-01-06  57.200001  30.367353  32.061115  ...    NaN  2858700   71037271
# 2014-01-07  57.919998  30.602690  32.386261  ...    NaN  2480500  102486711
# 2014-01-08  58.230000  30.056353  32.275024  ...    NaN  3441900   90036218
#
# Price
# Ticker          IBM  JD      META      MSFT      ORCL PDD UBER
# Date
# 2014-01-02  4755639 NaN  43195500  30632200  18162100 NaN  NaN
# 2014-01-03  4250107 NaN  38246200  31134800  11693900 NaN  NaN
# 2014-01-06  4254919 NaN  68852600  43603700  15329400 NaN  NaN
# 2014-01-07  6205186 NaN  77207400  35802800  16792200 NaN  NaN
# 2014-01-08  4815470 NaN  56682400  59971700  16111600 NaN  NaN
#
# [5 rows x 72 columns]

# %%
print(type(df))
df.to_csv('../data/test_yahoo.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = yf.download(tickers="MSFT", period="7d", interval="1m")
# Print the data
print(df.head())
df['Close'].plot()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2024-02-16 15:55:00-05:00  403.670013  404.029999  403.640015  403.899994
# 2024-02-16 15:56:00-05:00  403.910004  403.910004  403.649994  403.670013
# 2024-02-16 15:57:00-05:00  403.660004  403.799988  403.589996  403.799988
# 2024-02-16 15:58:00-05:00  403.799988  404.040009  403.690002  403.769989
# 2024-02-16 15:59:00-05:00  403.769989  404.059998  403.760010  404.059998
#
#                             Adj Close  Volume
# Datetime
# 2024-02-16 15:55:00-05:00  403.899994   88672
# 2024-02-16 15:56:00-05:00  403.670013  111098
# 2024-02-16 15:57:00-05:00  403.799988  110464
# 2024-02-16 15:58:00-05:00  403.769989  143546
# 2024-02-16 15:59:00-05:00  404.059998  303897
# <Axes: xlabel='Datetime'>
