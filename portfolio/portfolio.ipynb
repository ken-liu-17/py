# %%
import warnings
import yfinance as yf
warnings.simplefilter(action='ignore', category=FutureWarning)

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import numpy as np
import pandas as pd
from alpha import Alpha
from math import floor
from portfolio import Portfolio

# %%
print('Alpha...')
alpha = Alpha()
alpha.generate() 
print('Portfolio...')
portfolio = Portfolio(float(1e8), alpha)
portfolio.buildByPrevAdjClose()
# Out:
# Alpha...
# Portfolio...

# %%
print(portfolio.portfolio.head())
print(portfolio.pnL.head())
portfolio.pnL.cumsum().plot()
plt.show()
# Out:
#                AAPL       AMD     AMZN     BABA     BIDU     GOOG      IBM  \
# Date
# 2023-01-03 -57503.0 -111572.0 -83230.0 -78700.0 -59958.0 -79630.0 -53450.0
# 2023-01-04  56916.0  110467.0 -83895.0  69658.0  54211.0 -80519.0  53057.0
# 2023-01-05 -57526.0 -114597.0 -85934.0  69218.0  53896.0 -82319.0 -53617.0
# 2023-01-06  55484.0  111676.0  82979.0  67401.0  53681.0  81021.0  52651.0
# 2023-01-09  55258.0  106229.0  81763.0  65315.0  53548.0  80437.0 -52706.0
#
#                   JD     META     MSFT     NVDA     ORCL      PDD      UBER
# Date
# 2023-01-03 -125785.0 -57322.0 -30134.0 -49919.0 -86950.0 -84500.0 -281658.0
# 2023-01-04  109686.0  56139.0 -31512.0  48450.0  86167.0  78441.0  275679.0
# 2023-01-05 -110019.0 -56329.0 -32475.0 -50094.0 -86341.0  74849.0 -279563.0
# 2023-01-06 -112757.0  54994.0  32096.0  48092.0  84980.0  74435.0  270562.0
# 2023-01-09 -114847.0 -55228.0  31787.0  45725.0  83918.0 -74778.0  260688.0
#                      pnL
# Date
# 2023-01-03  0.000000e+00
# 2023-01-04  4.165049e+06
# 2023-01-05  1.787378e+06
# 2023-01-06  2.236169e+06
# 2023-01-09  1.745767e+06

# %%
print('sharpe ratio=', portfolio.sharpeRatio())
# Out:
# pnL    0.016573
# dtype: float64
# pnL    0.016573
# dtype: float64 0.007219437504579937
# sharpe ratio= 36.442085208193184

# %%
portfolio.buildByOpen()
print(portfolio.portfolio.head())
print(portfolio.pnL.head())
portfolio.pnL.cumsum().plot()
plt.show()
print('sharpe ratio=', portfolio.sharpeRatio())
# Out:
#                AAPL       AMD     AMZN     BABA     BIDU     GOOG      IBM  \
# Date
# 2023-01-03 -54826.0 -108225.0 -83581.0 -78398.0 -60094.0 -79515.0 -50622.0
# 2023-01-04  56291.0  109890.0 -82528.0  72259.0  56447.0 -78484.0  50277.0
# 2023-01-05 -56185.0 -111346.0 -83708.0  70442.0  55660.0 -81104.0 -50146.0
# 2023-01-06  56684.0  113109.0  86027.0  68608.0  54563.0  81763.0  50167.0
# 2023-01-09  54747.0  107865.0  81669.0  63781.0  52602.0  80081.0 -49575.0
#
#                   JD     META     MSFT     NVDA     ORCL      PDD      UBER
# Date
# 2023-01-03 -123216.0 -58157.0 -29384.0 -48096.0 -86611.0 -83532.0 -281547.0
# 2023-01-04  115805.0  56075.0 -30751.0  49034.0  84832.0  80103.0  277608.0
# 2023-01-05 -112485.0 -56630.0 -31438.0 -49291.0 -84033.0  79365.0 -277608.0
# 2023-01-06 -111685.0  55383.0  32030.0  49349.0  84291.0  75810.0  276212.0
# 2023-01-09 -110212.0 -54459.0  31542.0  46734.0  82253.0 -72142.0  261643.0
#                      pnL
# Date
# 2023-01-03  1.509001e+06
# 2023-01-04  1.107799e+06
# 2023-01-05  2.297996e+06
# 2023-01-06  9.958288e+05
# 2023-01-09  7.608240e+05
# pnL    0.010059
# dtype: float64
# pnL    0.010059
# dtype: float64 0.006746263627574024
# sharpe ratio= 23.669990811129182
